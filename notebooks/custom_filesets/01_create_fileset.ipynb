# %% [markdown]
# # Create a Custom FileSet
#
# A **FileSet** is a collection of documents with optional metadata that you can use as a data source for question generation. This notebook walks through creating a FileSet, defining a metadata schema, and uploading documents.
#
# We'll create synthetic quarterly investor reports for two companies — APEX Technologies and Vanguard Industries (VGI) — spanning Q1 2024 through Q1 2025. Notebooks 2 and 3 in this series use this FileSet for question generation and advanced features.

# %%
# %pip install lightningrod-ai python-dotenv -q

from IPython.display import clear_output
clear_output()

# %% [markdown]
# ## Set up the client
#
# Sign up at [dashboard.lightningrod.ai](https://dashboard.lightningrod.ai/?redirect=/api) to get your API key and **$50 of free credits**.
#
# - **Google Colab**: Go to the Secrets section (key icon in left sidebar) and add a secret named `LIGHTNINGROD_API_KEY`
# - **Local Jupyter**: Set the `LIGHTNINGROD_API_KEY` environment variable, or you'll be prompted to enter it

# %%
from dotenv import load_dotenv
from lightningrod import LightningRod
from lightningrod.utils import config

load_dotenv()
api_key = config.get_config_value("LIGHTNINGROD_API_KEY")

lr = LightningRod(api_key=api_key)

# %% [markdown]
# ## Create FileSet with Metadata Schema
#
# We define a metadata schema with two fields:
# - **ticker** — the company ticker symbol (e.g. `APEX`, `VGI`)
# - **quarter** — the fiscal quarter (e.g. `Q1 2024`)
#
# These metadata fields can later be used to filter which documents are included in question generation.

# %%
from lightningrod._generated.models import (
    FileSetMetadataSchemaInput,
    MetadataFieldDefinitionInput,
    MetadataFieldType,
)

schema = FileSetMetadataSchemaInput(fields=[
    MetadataFieldDefinitionInput(
        name="ticker", field_type=MetadataFieldType.STRING, required=True,
        description="Company ticker symbol"
    ),
    MetadataFieldDefinitionInput(
        name="quarter", field_type=MetadataFieldType.STRING, required=True,
        description="Fiscal quarter (e.g. Q1 2024)"
    ),
])

fileset = lr.filesets.create(
    name="Quarterly Reports - APEX & VGI",
    description="Synthetic quarterly investor reports for APEX Technologies and Vanguard Industries (Q1 2024 - Q1 2025).",
    metadata_schema=schema,
)
print(f"Created FileSet: {fileset.id}")
print(f"  Name: {fileset.name}")
# Out:
# Created FileSet: 19ffe46a-9fa8-4ad5-a043-62a23384d2f9
#   Name: Quarterly Reports - APEX & VGI

# %% [markdown]
# ## Create Example Quarterly Reports
#
# We'll create 10 documents — 5 quarters each for APEX Technologies and Vanguard Industries (VGI), covering Q1 2024 through Q1 2025. Each document includes financial highlights, business updates, and forward guidance.

# %%
from datetime import datetime

documents = [
    # ── APEX Technologies ──
    {
        "filename": "apex_q1_2024.txt",
        "content": (
            "APEX Technologies Inc. — Quarterly Investor Report, Q1 2024\n"
            "Period ending March 31, 2024\n\n"
            "Financial Highlights:\n"
            "- Revenue: $2.14 billion (up 12% YoY)\n"
            "- Earnings per share (EPS): $1.87\n"
            "- Operating margin: 18.3%\n"
            "- Free cash flow: $310 million\n\n"
            "Business Update:\n"
            "APEX's cloud infrastructure division drove most of the growth, with enterprise contracts "
            "increasing by 23% quarter-over-quarter. The company launched its new AI-accelerated compute "
            "platform, AXCompute 3.0, which has already secured commitments from 14 Fortune 500 clients.\n\n"
            "Guidance:\n"
            "Management expects Q2 2024 revenue between $2.20B and $2.30B, with full-year 2024 revenue "
            "projected at $9.0B-$9.3B. The company plans to invest $400 million in data center expansion "
            "during Q2, which may temporarily compress margins to 16-17%.\n"
        ),
        "metadata": {"ticker": "APEX", "quarter": "Q1 2024"},
        "file_date": datetime(2024, 3, 31),
    },
    {
        "filename": "apex_q2_2024.txt",
        "content": (
            "APEX Technologies Inc. — Quarterly Investor Report, Q2 2024\n"
            "Period ending June 30, 2024\n\n"
            "Financial Highlights:\n"
            "- Revenue: $2.28 billion (up 15% YoY)\n"
            "- Earnings per share (EPS): $1.92\n"
            "- Operating margin: 16.8% (compressed due to planned data center investment)\n"
            "- Free cash flow: $245 million\n\n"
            "Business Update:\n"
            "Revenue came in within guidance range. The $400M data center expansion in Northern Virginia "
            "is on schedule for Q4 completion. AXCompute 3.0 adoption exceeded expectations with 22 new "
            "enterprise clients added during the quarter. International revenue grew 28% YoY, now "
            "representing 34% of total revenue.\n\n"
            "Guidance:\n"
            "Q3 2024 revenue expected at $2.35B-$2.45B. Management raised full-year 2024 guidance to "
            "$9.2B-$9.5B. Operating margin expected to recover to 18%+ in Q3 as data center capex normalizes.\n"
        ),
        "metadata": {"ticker": "APEX", "quarter": "Q2 2024"},
        "file_date": datetime(2024, 6, 30),
    },
    {
        "filename": "apex_q3_2024.txt",
        "content": (
            "APEX Technologies Inc. — Quarterly Investor Report, Q3 2024\n"
            "Period ending September 30, 2024\n\n"
            "Financial Highlights:\n"
            "- Revenue: $2.41 billion (up 18% YoY)\n"
            "- Earnings per share (EPS): $2.11\n"
            "- Operating margin: 19.1% (recovered as expected)\n"
            "- Free cash flow: $380 million\n\n"
            "Business Update:\n"
            "Strong quarter across all divisions. The Northern Virginia data center is 85% complete "
            "and expected to begin serving clients in early Q4. AXCompute 3.0 now has 58 enterprise "
            "clients, making it the fastest-growing product in company history. APEX announced a "
            "strategic partnership with Meridian Health Systems for AI-powered diagnostics infrastructure.\n\n"
            "Guidance:\n"
            "Q4 2024 revenue expected at $2.50B-$2.60B. Full-year 2024 guidance raised again to "
            "$9.4B-$9.6B. Management announced plans to explore an acquisition in the cybersecurity "
            "space during Q1 2025, budgeted at up to $1.2 billion.\n"
        ),
        "metadata": {"ticker": "APEX", "quarter": "Q3 2024"},
        "file_date": datetime(2024, 9, 30),
    },
    {
        "filename": "apex_q4_2024.txt",
        "content": (
            "APEX Technologies Inc. — Quarterly Investor Report, Q4 2024\n"
            "Period ending December 31, 2024\n\n"
            "Financial Highlights:\n"
            "- Revenue: $2.58 billion (up 21% YoY)\n"
            "- Earnings per share (EPS): $2.24\n"
            "- Operating margin: 20.2%\n"
            "- Free cash flow: $420 million\n"
            "- Full-year 2024 revenue: $9.41 billion\n\n"
            "Business Update:\n"
            "Record quarter for APEX. The Northern Virginia data center came online in November, adding "
            "35% more compute capacity. Total AXCompute 3.0 enterprise clients reached 74. The company "
            "completed due diligence on CyberShield Corp, a cybersecurity firm, and expects to close "
            "the $980 million acquisition in Q1 2025. International revenue now at 37% of total.\n\n"
            "Guidance:\n"
            "FY2025 revenue guidance: $10.5B-$11.0B (12-17% growth). Q1 2025 revenue expected at "
            "$2.55B-$2.65B, with margin temporarily impacted by CyberShield integration costs. "
            "Management projects the acquisition will be accretive to earnings by Q3 2025.\n"
        ),
        "metadata": {"ticker": "APEX", "quarter": "Q4 2024"},
        "file_date": datetime(2024, 12, 31),
    },
    {
        "filename": "apex_q1_2025.txt",
        "content": (
            "APEX Technologies Inc. — Quarterly Investor Report, Q1 2025\n"
            "Period ending March 31, 2025\n\n"
            "Financial Highlights:\n"
            "- Revenue: $2.63 billion (up 23% YoY)\n"
            "- Earnings per share (EPS): $2.08 (impacted by CyberShield integration)\n"
            "- Operating margin: 17.4% (integration costs as projected)\n"
            "- Free cash flow: $290 million\n\n"
            "Business Update:\n"
            "The CyberShield acquisition closed on February 14, 2025 for $980 million. Integration is "
            "proceeding on schedule. Combined cybersecurity revenue contributed $180M to the quarter. "
            "AXCompute 3.0 enterprise clients grew to 91. The company launched AXCompute 4.0 preview "
            "program with next-generation AI inference capabilities, targeting general availability in Q3 2025.\n\n"
            "Guidance:\n"
            "Q2 2025 revenue expected at $2.75B-$2.85B. Full-year 2025 guidance maintained at "
            "$10.5B-$11.0B. Operating margin expected to recover to 19%+ by Q3 2025 as integration "
            "costs wind down.\n"
        ),
        "metadata": {"ticker": "APEX", "quarter": "Q1 2025"},
        "file_date": datetime(2025, 3, 31),
    },
    # ── Vanguard Industries (VGI) ──
    {
        "filename": "vanguard_q1_2024.txt",
        "content": (
            "Vanguard Industries Inc. (VGI) — Quarterly Investor Report, Q1 2024\n"
            "Period ending March 31, 2024\n\n"
            "Financial Highlights:\n"
            "- Revenue: $1.45 billion (down 3% YoY)\n"
            "- Earnings per share (EPS): $0.89\n"
            "- Operating margin: 11.2%\n"
            "- Free cash flow: $95 million\n\n"
            "Business Update:\n"
            "Vanguard's legacy manufacturing automation division continued to face headwinds from reduced "
            "industrial capex spending. However, the newer Robotics-as-a-Service (RaaS) segment grew 45% YoY, "
            "now representing 18% of total revenue. The company signed a landmark $200M multi-year contract "
            "with GlobalAuto Corp for factory automation.\n\n"
            "Guidance:\n"
            "Q2 2024 revenue expected at $1.48B-$1.55B. Management is evaluating a restructuring of the "
            "legacy division to reduce costs by $120M annually, with a decision expected by end of Q2. "
            "Full-year 2024 revenue projected at $6.0B-$6.3B.\n"
        ),
        "metadata": {"ticker": "VGI", "quarter": "Q1 2024"},
        "file_date": datetime(2024, 3, 31),
    },
    {
        "filename": "vanguard_q2_2024.txt",
        "content": (
            "Vanguard Industries Inc. (VGI) — Quarterly Investor Report, Q2 2024\n"
            "Period ending June 30, 2024\n\n"
            "Financial Highlights:\n"
            "- Revenue: $1.52 billion (up 2% YoY)\n"
            "- Earnings per share (EPS): $0.78 (includes $0.15 restructuring charges)\n"
            "- Operating margin: 9.1% (impacted by restructuring)\n"
            "- Free cash flow: $65 million\n\n"
            "Business Update:\n"
            "The board approved a comprehensive restructuring plan for the legacy manufacturing division. "
            "The plan involves closing 3 facilities and reducing headcount by 1,200, with expected annual "
            "savings of $130M once fully implemented by Q1 2025. One-time restructuring charges of $85M "
            "will be recognized across Q2-Q3. RaaS segment continued strong growth at 52% YoY.\n\n"
            "Guidance:\n"
            "Q3 2024 revenue expected at $1.50B-$1.58B (remaining restructuring charges will compress "
            "margins). Full-year 2024 guidance narrowed to $6.1B-$6.3B. RaaS segment expected to reach "
            "25% of revenue by year-end.\n"
        ),
        "metadata": {"ticker": "VGI", "quarter": "Q2 2024"},
        "file_date": datetime(2024, 6, 30),
    },
    {
        "filename": "vanguard_q3_2024.txt",
        "content": (
            "Vanguard Industries Inc. (VGI) — Quarterly Investor Report, Q3 2024\n"
            "Period ending September 30, 2024\n\n"
            "Financial Highlights:\n"
            "- Revenue: $1.56 billion (up 5% YoY)\n"
            "- Earnings per share (EPS): $0.91 (includes final $0.08 restructuring charge)\n"
            "- Operating margin: 12.4%\n"
            "- Free cash flow: $140 million\n\n"
            "Business Update:\n"
            "Restructuring is substantially complete. Two of three facility closures are done, with the "
            "third expected in early Q4. Cost savings are already materializing ahead of schedule — $38M "
            "realized this quarter. RaaS revenue hit $390M (25% of total), driven by expansion of the "
            "GlobalAuto contract and 8 new mid-market clients. Vanguard announced development of an "
            "AI-powered predictive maintenance platform targeting launch in Q2 2025.\n\n"
            "Guidance:\n"
            "Q4 2024 revenue expected at $1.60B-$1.68B with margins expanding to 14%+ as restructuring "
            "charges end. Full-year 2024 guidance raised to $6.2B-$6.4B. Management projects the RaaS "
            "segment will reach $2B+ annual run-rate by mid-2025.\n"
        ),
        "metadata": {"ticker": "VGI", "quarter": "Q3 2024"},
        "file_date": datetime(2024, 9, 30),
    },
    {
        "filename": "vanguard_q4_2024.txt",
        "content": (
            "Vanguard Industries Inc. (VGI) — Quarterly Investor Report, Q4 2024\n"
            "Period ending December 31, 2024\n\n"
            "Financial Highlights:\n"
            "- Revenue: $1.65 billion (up 9% YoY)\n"
            "- Earnings per share (EPS): $1.14\n"
            "- Operating margin: 14.7%\n"
            "- Free cash flow: $210 million\n"
            "- Full-year 2024 revenue: $6.18 billion\n\n"
            "Business Update:\n"
            "Strong finish to the year. Restructuring fully complete with annualized savings now tracking "
            "at $135M (above initial $130M target). RaaS segment hit $450M in Q4 revenue (27% of total), "
            "with the annual run-rate approaching $1.8B. The predictive maintenance platform entered beta "
            "testing with 5 pilot customers. Vanguard also announced a strategic investment of $50M in "
            "NanoFab Technologies, a semiconductor equipment startup.\n\n"
            "Guidance:\n"
            "FY2025 revenue guidance: $7.0B-$7.4B (13-20% growth). Q1 2025 revenue expected at "
            "$1.68B-$1.75B. RaaS segment projected to reach 35% of total revenue by year-end 2025. "
            "Predictive maintenance platform GA expected Q2 2025.\n"
        ),
        "metadata": {"ticker": "VGI", "quarter": "Q4 2024"},
        "file_date": datetime(2024, 12, 31),
    },
    {
        "filename": "vanguard_q1_2025.txt",
        "content": (
            "Vanguard Industries Inc. (VGI) — Quarterly Investor Report, Q1 2025\n"
            "Period ending March 31, 2025\n\n"
            "Financial Highlights:\n"
            "- Revenue: $1.74 billion (up 20% YoY)\n"
            "- Earnings per share (EPS): $1.22\n"
            "- Operating margin: 15.3%\n"
            "- Free cash flow: $235 million\n\n"
            "Business Update:\n"
            "Exceptional quarter driven by RaaS acceleration. RaaS segment revenue reached $540M (31% of "
            "total), growing 107% YoY. The predictive maintenance platform completed beta with all 5 pilot "
            "customers converting to paid contracts. GA launch moved up to late April 2025. Legacy division "
            "stabilized with $34M in quarterly cost savings fully flowing through. GlobalAuto expanded their "
            "contract by an additional $150M over 3 years. NanoFab investment yielded a partnership for "
            "exclusive robotics integration in next-gen semiconductor fabs.\n\n"
            "Guidance:\n"
            "Q2 2025 revenue expected at $1.82B-$1.90B. Full-year 2025 guidance raised to $7.3B-$7.6B. "
            "Management expects RaaS to reach 35-38% of total revenue by year-end.\n"
        ),
        "metadata": {"ticker": "VGI", "quarter": "Q1 2025"},
        "file_date": datetime(2025, 3, 31),
    },
]

print(f"Prepared {len(documents)} documents for upload")
for doc in documents:
    print(f"  {doc['filename']} — {doc['metadata']['ticker']} {doc['metadata']['quarter']} ({doc['file_date'].date()})")
# Out:
# Prepared 10 documents for upload
#   apex_q1_2024.txt — APEX Q1 2024 (2024-03-31)
#   apex_q2_2024.txt — APEX Q2 2024 (2024-06-30)
#   apex_q3_2024.txt — APEX Q3 2024 (2024-09-30)
#   apex_q4_2024.txt — APEX Q4 2024 (2024-12-31)
#   apex_q1_2025.txt — APEX Q1 2025 (2025-03-31)
#   vanguard_q1_2024.txt — VGI Q1 2024 (2024-03-31)
#   vanguard_q2_2024.txt — VGI Q2 2024 (2024-06-30)
#   vanguard_q3_2024.txt — VGI Q3 2024 (2024-09-30)
#   vanguard_q4_2024.txt — VGI Q4 2024 (2024-12-31)
#   vanguard_q1_2025.txt — VGI Q1 2025 (2025-03-31)

# %% [markdown]
# ## Upload Documents

# %%
import tempfile
import os

uploaded_files = []
for doc in documents:
    tmp = tempfile.NamedTemporaryFile(mode="w", suffix=".txt", delete=False, prefix=doc["filename"].replace(".txt", "_"))
    tmp.write(doc["content"])
    tmp.close()

    file_result = lr.filesets.files.upload(
        file_set_id=fileset.id,
        file_path=tmp.name,
        metadata=doc["metadata"],
        file_date=doc["file_date"],
    )
    uploaded_files.append(file_result)
    print(f"Uploaded: {doc['filename']} -> {file_result.id} (status: {file_result.status})")

    os.unlink(tmp.name)

print(f"\nUploaded {len(uploaded_files)} files to FileSet {fileset.id}")
# Out:
# Uploaded: apex_q1_2024.txt -> 1a89a75c-ed51-4402-9027-09faf69b5025 (status: PENDING)
# Uploaded: apex_q2_2024.txt -> 024d0c94-392c-44a5-94b2-412b433b82bb (status: PENDING)
# Uploaded: apex_q3_2024.txt -> 23ab86c7-1fff-46bc-948b-4c41e98acb02 (status: PENDING)
# Uploaded: apex_q4_2024.txt -> 236b68e5-c48b-41e9-873c-3bf54521b6e0 (status: PENDING)
# Uploaded: apex_q1_2025.txt -> 9d820b9b-e70e-42ec-bb94-afb187dfbf1f (status: PENDING)
# Uploaded: vanguard_q1_2024.txt -> 62afabec-5198-4323-929c-b3c885838c4c (status: PENDING)
# Uploaded: vanguard_q2_2024.txt -> 3e714976-8bf7-4e7c-a309-cc599069883d (status: PENDING)
# Uploaded: vanguard_q3_2024.txt -> 465899d9-8caf-44fa-a16d-89fa6f36daee (status: PENDING)
# Uploaded: vanguard_q4_2024.txt -> 5df20e15-abae-4af2-9965-c511b8082835 (status: PENDING)
# Uploaded: vanguard_q1_2025.txt -> 6ec3b3ca-3e35-48f3-912f-e3652df8b8fa (status: PENDING)
#
# Uploaded 10 files to FileSet 19ffe46a-9fa8-4ad5-a043-62a23384d2f9

# %% [markdown]
# ## Wait for File Processing
#
# Files need to be processed before they can be used for question generation. This typically takes 1-2 minutes.

# %%
import time

POLL_INTERVAL = 10  # seconds
TIMEOUT = 600  # 10 minutes

start = time.time()
while time.time() - start < TIMEOUT:
    files_response = lr.filesets.files.list(fileset.id)
    files = files_response.files

    statuses = [str(f.status) for f in files]
    active_count = statuses.count("ACTIVE")
    failed_count = statuses.count("FAILED")
    pending_count = statuses.count("PENDING")
    processing_count = statuses.count("PROCESSING")

    elapsed = int(time.time() - start)
    print(f"[{elapsed}s] ACTIVE={active_count} PROCESSING={processing_count} PENDING={pending_count} FAILED={failed_count}")

    for f in files:
        if str(f.status) == "FAILED":
            print(f"  FAILED: {f.original_file_name} — {f.status_message}")

    if pending_count == 0 and processing_count == 0:
        break

    time.sleep(POLL_INTERVAL)
else:
    print(f"TIMEOUT after {TIMEOUT}s — some files still processing")

print(f"\nFinal: {active_count} active, {failed_count} failed out of {len(files)} files")
# Out:
# [0s] ACTIVE=7 PROCESSING=2 PENDING=1 FAILED=0
# [11s] ACTIVE=9 PROCESSING=1 PENDING=0 FAILED=0
# [23s] ACTIVE=10 PROCESSING=0 PENDING=0 FAILED=0
#
# Final: 10 active, 0 failed out of 10 files

# %% [markdown]
# ## Verify Uploaded Files

# %%
files_response = lr.filesets.files.list(fileset.id)
for f in files_response.files:
    print(f"File: {f.original_file_name}")
    print(f"  ID: {f.id}  |  Status: {f.status}  |  Size: {f.size_bytes} bytes")
    print(f"  Metadata: {f.metadata}")
    print()
# Out:
# File: apex_q2_2024_d15xfzpz.txt
#   ID: 024d0c94-392c-44a5-94b2-412b433b82bb  |  Status: ACTIVE  |  Size: 810 bytes
#   Metadata: FileSetFileMetadataType0(additional_properties={'ticker': 'APEX', 'quarter': 'Q2 2024', 'file_date': 1719705600})
#
# File: apex_q1_2024_c9_c62t4.txt
#   ID: 1a89a75c-ed51-4402-9027-09faf69b5025  |  Status: ACTIVE  |  Size: 788 bytes
#   Metadata: FileSetFileMetadataType0(additional_properties={'ticker': 'APEX', 'quarter': 'Q1 2024', 'file_date': 1711843200})
#
# File: apex_q4_2024_s3em8d9f.txt
#   ID: 236b68e5-c48b-41e9-873c-3bf54521b6e0  |  Status: ACTIVE  |  Size: 912 bytes
#   Metadata: FileSetFileMetadataType0(additional_properties={'ticker': 'APEX', 'quarter': 'Q4 2024', 'file_date': 1735603200})
#
# File: apex_q3_2024_fq2n8c4n.txt
#   ID: 23ab86c7-1fff-46bc-948b-4c41e98acb02  |  Status: ACTIVE  |  Size: 876 bytes
#   Metadata: FileSetFileMetadataType0(additional_properties={'ticker': 'APEX', 'quarter': 'Q3 2024', 'file_date': 1727654400})
#
# ...

# %% [markdown]
# ## Your FileSet ID
#
# Copy this ID to use in notebooks 2 and 3.

# %%
print(f"FileSet ID: {fileset.id}")
print(f"\nPaste this value into the fileset_id variable in the next notebooks.")
# Out:
# FileSet ID: 19ffe46a-9fa8-4ad5-a043-62a23384d2f9
#
# Paste this value into the fileset_id variable in the next notebooks.
