# %% [markdown]
# # News Search as Data Source
#
# This notebook demonstrates how to use news search (based on Google News) as a data source for generating forecasting questions. This provides accesss to recent news articles, and filtering options.

# %%
# %pip install -e ..
# %pip install dotenv

from IPython.display import clear_output
clear_output()

# %%
import os
from dotenv import load_dotenv
from lightningrod import LightningRod

load_dotenv()

api_key = os.getenv("LIGHTNINGROD_API_KEY")
base_url = os.getenv("LIGHTNINGROD_BASE_URL", "https://api.lightningrod.ai/api/public/v1")

if not api_key:
    raise ValueError("LIGHTNINGROD_API_KEY is not set")

# Note: base_url param can be omitted
client = LightningRod(api_key=api_key, base_url=base_url)

# %% [markdown]
# ## Configure News Seed Generator
#
# The `NewsSeedGenerator` searches Google News for articles matching your query. You can specify date ranges, search queries, and how many articles to fetch per interval.

# %%
from datetime import datetime
from lightningrod import NewsSeedGenerator

seed_generator = NewsSeedGenerator(
    start_date=datetime(2025, 1, 1),
    end_date=datetime(2025, 1, 31),
    interval_duration_days=7,
    search_query="AI technology announcements",
    articles_per_search=20,
)

# %% [markdown]
# ## Configure Question Generator
#
# The question generator creates forecasting questions from the news articles. Use examples and bad_examples to guide the model, and FilterCriteria to ensure quality.

# %%
from lightningrod import AnswerType, AnswerTypeEnum, QuestionGenerator, WebSearchLabeler, QuestionRenderer, QuestionPipeline

answer_type = AnswerType(answer_type=AnswerTypeEnum.BINARY)

question_generator = QuestionGenerator(
    instructions=(
        "Generate forward-looking questions about AI technology announcements. "
        "Questions should be about future events or outcomes that can be verified later."
    ),
    examples=[
        "Will OpenAI release a new model in Q2 2025?",
        "Will Google announce a new AI product this month?",
        "Will Apple integrate AI features into iOS 19?",
    ],
    bad_examples=[
        "What did OpenAI announce?",
        "Who is the CEO of Google?",
        "When was ChatGPT released?",
    ],
    answer_type=answer_type,
)

# Labeler automatically finds answers to questions using web search
labeler = WebSearchLabeler(
    answer_type=answer_type,
    confidence_threshold=0.5,
)

# Renderer formats the question output
renderer = QuestionRenderer(
    answer_type=answer_type,
)

pipeline_config = QuestionPipeline(
    seed_generator=seed_generator,
    question_generator=question_generator,
    labeler=labeler,
    renderer=renderer,
)

# %% [markdown]
# ## Run the Pipeline
#
# Combine all components into a QuestionPipeline and run it to generate your dataset.

# %%
dataset = client.transforms.run(pipeline_config, max_questions=10) # keep max questions low when testing

# %% [markdown]
# > Note: This can take a few minutes to complete processing.

# %% [markdown]
# ## View Results
#
# Inspect the generated questions and answers. Each sample contains `seed`, `question`, `label`, `prompt`, and optional `context` and `meta` fields. See [API.md](../API.md) for the complete sample structure.

# %%
# %pip install pandas

from IPython.display import clear_output
clear_output()

# %%
import pandas as pd

# Download samples to memory
samples = dataset.download()
print(f"Generated {dataset.num_rows} samples\n")

# Convert cached samples to a list of dictionaries
rows = dataset.flattened()

df = pd.DataFrame(rows)
df
# Out:
# Generated 12 samples
#                                question.question_text   label.label  \
# 0   Will the Asian Journal of Law and Society publ...             1
# 1   Will Oracle announce a general availability re...             1
# 2   Will Microsoft release Project Spark to the ge...             0
# 3   Will Alibaba's Qwen2.5-Max model reach the #1 ...             0
# 4   Will NYCEDC successfully place CUNY students i...             1
# 5   Will Meta end the year 2025 with at least 1.3 ...  Undetermined
# 6   Will a third-party audit or independent resear...             0
# 7   Will VideaHealth announce the official release...             1
# 8   Will DeepSeek release a new open-source large ...  Undetermined
# 9   Will Arteria AI's research arm, Arteria Café, ...  Undetermined
# 10  Will Microsoft spend at least $80 billion on A...             0
# 11  Will Alibaba's Qwen series maintain a higher r...  Undetermined
#
#     label.label_confidence label.resolution_date  \
# 0                      1.0   2025-01-15T00:00:00
# 1                      0.9   2025-10-14T00:00:00
# 2                      1.0   2016-05-13T00:00:00
# 3                      0.9   2025-02-06T00:00:00
# 4                      1.0   2025-08-27T00:00:00
# 5                      0.6                   NaN
# 6                      0.9   2025-01-28T00:00:00
# 7                      1.0   2025-07-30T00:00:00
# 8                      0.4                   NaN
# 9                      0.7                   NaN
# 10                     1.0   2025-01-06T00:00:00
# 11                     1.0                   NaN
#
#                                       label.reasoning  \
# 0   The Asian Journal of Law and Society is defini...
# 1   Oracle made significant announcements regardin...
# 2   Microsoft officially released Project Spark on...
# 3   Alibaba's Qwen2.5-Max model did not reach the ...
# 4   The New York City Economic Corporation (NYCEDC...
# 5   Mark Zuckerberg, CEO of Meta, stated in a Face...
# 6   DeepSeek itself claimed a training cost of app...
# 7   VideaHealth officially announced the launch of...
# 8   The question asks whether DeepSeek released a ...
# 9   Arteria AI announced the launch of its dedicat...
# 10  Microsoft announced plans in January 2025 to i...
# 11  The question asks to predict the relative rank...
#
#                                  label.answer_sources  \
# 0   https://vertexaisearch.cloud.google.com/ground...
# 1   https://vertexaisearch.cloud.google.com/ground...
# 2   https://vertexaisearch.cloud.google.com/ground...
# 3   https://vertexaisearch.cloud.google.com/ground...
# 4   https://vertexaisearch.cloud.google.com/ground...
# 5   https://vertexaisearch.cloud.google.com/ground...
# 6   https://vertexaisearch.cloud.google.com/ground...
# 7   https://vertexaisearch.cloud.google.com/ground...
# 8   https://vertexaisearch.cloud.google.com/ground...
# 9   https://vertexaisearch.cloud.google.com/ground...
# 10  https://vertexaisearch.cloud.google.com/ground...
# 11                                                NaN
#
#                                                prompt  \
# 0   QUESTION:\nWill the Asian Journal of Law and S...
# 1   QUESTION:\nWill Oracle announce a general avai...
# 2   QUESTION:\nWill Microsoft release Project Spar...
# 3   QUESTION:\nWill Alibaba's Qwen2.5-Max model re...
# 4   QUESTION:\nWill NYCEDC successfully place CUNY...
# 5                                                 NaN
# 6   QUESTION:\nWill a third-party audit or indepen...
# 7   QUESTION:\nWill VideaHealth announce the offic...
# 8                                                 NaN
# 9                                                 NaN
# 10  QUESTION:\nWill Microsoft spend at least $80 b...
# 11                                                NaN
#
#                                        seed.seed_text  \
# 0   Title: Special Issue on AI Sovereignty and Int...
# 1   Title: Oracle debuts new AI agents as artifici...
# 2   Title: Advancing education to prepare for an A...
# 3   Title: Alibaba claims its AI model trounces De...
# 4   Title: Mayor Adams, NYCEDC Release First-Of-It...
# 5   Title: Meta Plans Record $65bn AI Investment a...
# 6   Title: China's DeepSeek faces questions over c...
# 7   Title: VideaHealth Raises $40M in Oversubscrib...
# 8   Title: Access to this page has been denied.\n\...
# 9   Title: Arteria AI Launches New Research Arm to...
# 10  Title: Tech Giants Have Been Spending Big on A...
# 11  Title: reuters.com\n\nURL Source: https://www....
#
#                                              seed.url seed.seed_creation_date  \
# 0   https://www.cambridge.org/core/journals/asian-...     2025-01-31T00:00:00
# 1   https://finance.yahoo.com/news/oracle-debuts-n...     2025-01-30T00:00:00
# 2   https://www.microsoft.com/en-us/education/blog...     2025-01-30T00:00:00
# 3   https://www.livescience.com/technology/artific...     2025-01-29T00:00:00
# 4   https://www.nyc.gov/mayors-office/news/2025/01...     2025-01-31T00:00:00
# 5   https://technologymagazine.com/articles/metas-...     2025-01-30T00:00:00
# 6   https://www.aljazeera.com/news/2025/1/29/ai-ga...     2025-01-29T00:00:00
# 7   https://www.businesswire.com/news/home/2025012...     2025-01-29T00:00:00
# 8   https://www.investors.com/news/technology/ai-s...     2025-01-30T00:00:00
# 9   https://www.businesswire.com/news/home/2025012...     2025-01-29T00:00:00
# 10  https://www.investopedia.com/will-msft-meta-am...     2025-01-29T00:00:00
# 11  https://www.reuters.com/technology/artificial-...     2025-01-29T00:00:00
#
#               seed.search_query  is_valid  \
# 0   AI technology announcements      True
# 1   AI technology announcements      True
# 2   AI technology announcements      True
# 3   AI technology announcements      True
# 4   AI technology announcements      True
# 5   AI technology announcements     False
# 6   AI technology announcements      True
# 7   AI technology announcements      True
# 8   AI technology announcements     False
# 9   AI technology announcements     False
# 10  AI technology announcements      True
# 11  AI technology announcements     False
#
#                           meta.sample_id  \
# 0   45320d89-977d-4f29-9254-97c925a9554b
# 1   c5546940-d9a0-40d0-bc9a-14dc363defde
# 2   64d0a7e6-48b7-404d-8dce-d2b7a233e962
# 3   75489412-fa2c-49ec-808a-653b9fda038b
# 4   f4e2353c-3700-4d1a-b6eb-98f80c7d6d95
# 5   252038e1-9ca6-4283-89c9-de933cba3270
# 6   31e28292-78fd-4a2e-a7e7-a1e26f2430c8
# 7   9da80cde-dfdd-4449-871e-2b0ea4cb6830
# 8   2c7ff91b-dd4f-46dd-ab33-a8032a8283af
# 9   5a108ab6-6c3e-44bc-94bd-c7707f937e5b
# 10  f1f332ca-e920-45a2-af43-cafb9d2689de
# 11  086c3655-411d-4f22-889f-34e7d1a55dec
#
#                    meta.parent_sample_id  meta.processing_time_ms  \
# 0   e0cd79f4-a517-4201-b7c8-41a8160adbc1                 9390.237
# 1   4938598a-c929-4918-be2c-820e00b0bf08                16775.201
# 2   e1094f33-c976-4e7a-958b-b556359f7e42                 8457.427
# 3   87b1a593-d9d6-42d2-a441-18070ca54955                18403.397
# 4   1f2c3445-7cc1-42b5-b327-f1384c6f2906                10140.285
# 5   c450a2f2-1742-44b3-ba1d-eba87fb8ca00                19346.681
# 6   5cfe0d04-657a-4bd8-8949-12a57ded5b6f                17161.596
# 7   a62c404e-cac4-433e-af3a-7fe90ef965ba                 6583.710
# 8   4b1d67c3-2c0a-48f5-b9f7-54671e3e645a                30137.668
# 9   09f0c491-72b1-405d-b48c-e5a4e08e83b7                12470.074
# 10  2705e833-7a39-4006-b355-ee986793ee03                16268.864
# 11  bf6df2f3-064f-4826-b9b1-fc18603de7aa                 4614.217
#
#     meta.filter_reason
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5   Undetermined label
# 6                  NaN
# 7                  NaN
# 8   Undetermined label
# 9   Undetermined label
# 10                 NaN
# 11  Undetermined label
